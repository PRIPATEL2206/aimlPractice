# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\baps\AppData\Local\Temp\ipykernel_15024\1492400551.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv("csv/test_scores.csv")
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
df.plot()
# Out:
# <Axes: >

# %%
plt.scatter(df["cs"],df["math"])

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(df[["cs"]],df["math"])
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([0.88338816])

# %%
model.intercept_
# Out:
# 5.051167395956433

# %%
import joblib


joblib.dump(model,"mathScienceModel")
# Out:
# ['mathScienceModel']

# %%
m2=joblib.load("mathScienceModel")

# %%
m2.intercept_
# Out:
# 5.051167395956433
